# %% [markdown]
# # Otroške knjige
#
# Za projektno nalogo sem iz spletne strani www.goodreads.com zajela podatke iz treh različnih list, na katerih so po priljubljenosti ocenjene otroške knjige. Iz vsake od list sem zajela prvih 1200 knjig - po prvih 1200 knjigah namreč glasovi drastično upadejo, določeno mesto si deli tudi po deset knjig in več. Liste, ki sem si jih izbrala, so [Favorite books from my childhood](http://www.goodreads.com/list/show/226.Favorite_books_from_my_childhood) (nadalje lista 1), [What book got you hooked?](http://www.goodreads.com/list/show/651.What_Book_Got_You_Hooked_) (lista 2) in [Best children's books](http://www.goodreads.com/list/show/86.Best_Children_s_Books) (lista 3).
#
# Podatki so ločeni v pet csv datotek:
# * lista1.csv
# * lista2.csv
# * lista3.csv
# * avtorji.csv
# * naslovi.csv
#
# Liste vsebujejo mesto, na katerega se je knjiga uvrstila, id knjige in id avtorja, oceno, št. glasov in skupno oceno - ta je odvisna od števila glasov, ocene ter drugih dejavnikov, ki na spletni strani niso posebej specificirani.
# Datoteka avtorji vsebuje ime avtorja ter njegov id, datoteka naslovi pa naslov knjige in id knjige.

# %% [markdown]
# ## Uvod
#
# Naložimo datoteke in si oglejmo nekaj osnovnih tabel.

# %%
# naložimo paket
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
% matplotlib inline 


# naložimo razpredelnice, s katero bomo delali
avtorji = pd.read_csv('../csv_datoteke/avtor.csv', index_col='id_avt')
lista1 = pd.read_csv('../csv_datoteke/tabela1.csv')
lista2 = pd.read_csv('../csv_datoteke/tabela2.csv')
lista3 = pd.read_csv('../csv_datoteke/tabela3.csv')
naslovi = pd.read_csv('../csv_datoteke/naslov.csv', index_col='id_nasl')


# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 16 vrstic in stolpcev
pd.options.display.max_rows = 16
pd.options.display.max_columns = 16


#nastavitve za grafe
plt.style.use
plt.rcParams['figure.figsize'] = (15, 5)

# %%
# tabela avtorjev
avtorji
# Out:
#                            avtor
# id_avt
# 988142                E.B. White
# 2041     Frances Hodgson Burnett
# 1069006               C.S. Lewis
# 5350             L.M. Montgomery
# 1315           Louisa May Alcott
# 4273                  Roald Dahl
# 4489              Maurice Sendak
# 106        Madeleine L&#39;Engle
# ...                          ...
# 28939              Chris Raschka
# 2875079        Maribelle Cormack
# 38771               Taro Yashima
# 3092248             Peter  Brown
# 67906                 Lee Welles
# 78983         Oliver Butterworth
# 93133              Alison Lester
# 110570              Babette Cole
#
# [1252 rows x 1 columns]

# %%
# ena izmed list
lista1
# Out:
#       mesto  id_nasl   id_avt  ocena  st_glasov  ocena_skupaj
# 0         1    24178   988142   4.14    1021663        151594
# 1         2     2998     2041   4.11     657537        116234
# 2         3   100915  1069006   4.19    1487021        113719
# 3         4     8127     5350   4.22     509181        107096
# 4         5     1934     1315   4.03    1262538         98256
# 5         6    39988     4273   4.28     449574         94659
# 6         7     6310     4273   4.10     483822         81032
# 7         8    19543     4489   4.22     607025         74583
# ...     ...      ...      ...    ...        ...           ...
# 1192   1191   994547    10657   4.00        879           177
# 1193   1191  1143050     5326   3.97        110           177
# 1194   1191   921651      692   4.22      23934           177
# 1195   1191  1162351   101103   4.89          9           177
# 1196   1191   557226    10657   3.91       5216           177
# 1197   1191   129479    74445   4.05        766           177
# 1198   1199   122438  1041311   4.21       4623           176
# 1199   1199   858037    18959   3.99      24506           176
#
# [1200 rows x 6 columns]

# %%
# zgornja tabela, združena s tabelo avtorjev
lista3.join(avtorji, on = 'id_avt')
# Out:
#       mesto  id_nasl  id_avt  ocena  st_glasov  ocena_skupaj  \
# 0         1    19543    4489   4.22     607025        106056
# 1         2     4948    3362   4.28     289736        100936
# 2         3   370493  435477   4.38     673811         97748
# 3         4    23772   61105   4.29     452386         92798
# 4         5    32929   18479   4.27     247113         73731
# 5         6    24178  988142   4.14    1021663         69226
# 6         7    30119  435477   4.28     997917         63486
# 7         8   233093   61105   4.15     310680         62318
# ...     ...      ...     ...    ...        ...           ...
# 1192   1189    19336   11593   4.04       7847           128
# 1193   1189  2277310  173545   4.14       2092           128
# 1194   1189   644346   61105   4.20       2513           128
# 1195   1196   726931    8725   4.16        743           127
# 1196   1197   289866     214   4.36       1211           126
# 1197   1197   912131   93133   4.09       1373           126
# 1198   1199  3503661  110570   3.35         43           125
# 1199   1199   947148    5411   4.26        478           125
#
#                     avtor
# 0          Maurice Sendak
# 1              Eric Carle
# 2        Shel Silverstein
# 3               Dr. Seuss
# 4     Margaret Wise Brown
# 5              E.B. White
# 6        Shel Silverstein
# 7               Dr. Seuss
# ...                   ...
# 1192       Beatrix Potter
# 1193       Oliver Jeffers
# 1194            Dr. Seuss
# 1195        Tomie dePaola
# 1196        Norton Juster
# 1197        Alison Lester
# 1198         Babette Cole
# 1199       Cynthia Rylant
#
# [1200 rows x 7 columns]

# %%
# tabela naslovov
naslovi
# Out:
#                                                     naslov
# id_nasl
# 24178                                      Charlotte's Web
# 2998                                     The Secret Garden
# 100915   The Lion, the Witch, and the Wardrobe (Chronic...
# 8127       Anne of Green Gables (Anne of Green Gables, #1)
# 1934                       Little Women (Little Women, #1)
# 39988                                              Matilda
# 6310     Charlie and the Chocolate Factory (Charlie Buc...
# 19543                            Where the Wild Things Are
# ...                                                    ...
# 484831                                    The Enormous Egg
# 2277310                    The Way Back Home (The Boy, #3)
# 644346                               What Was I Scared Of?
# 726931                         Strega Nona's Magic Lessons
# 289866   The Dot and the Line: A Romance in Lower Mathe...
# 912131       Are We There Yet?: A Journey Around Australia
# 3503661                                          Drop Dead
# 947148               Mr. Putter &amp; Tabby Catch the Cold
#
# [2642 rows x 1 columns]

# %%
# listi pridružimo tabelo naslovov
lista3.join(naslovi, on = 'id_nasl')
# Out:
#       mesto  id_nasl  id_avt  ocena  st_glasov  ocena_skupaj  \
# 0         1    19543    4489   4.22     607025        106056
# 1         2     4948    3362   4.28     289736        100936
# 2         3   370493  435477   4.38     673811         97748
# 3         4    23772   61105   4.29     452386         92798
# 4         5    32929   18479   4.27     247113         73731
# 5         6    24178  988142   4.14    1021663         69226
# 6         7    30119  435477   4.28     997917         63486
# 7         8   233093   61105   4.15     310680         62318
# ...     ...      ...     ...    ...        ...           ...
# 1192   1189    19336   11593   4.04       7847           128
# 1193   1189  2277310  173545   4.14       2092           128
# 1194   1189   644346   61105   4.20       2513           128
# 1195   1196   726931    8725   4.16        743           127
# 1196   1197   289866     214   4.36       1211           126
# 1197   1197   912131   93133   4.09       1373           126
# 1198   1199  3503661  110570   3.35         43           125
# 1199   1199   947148    5411   4.26        478           125
#
#                                                  naslov
# 0                             Where the Wild Things Are
# 1                           The Very Hungry Caterpillar
# 2                                       The Giving Tree
# 3                                    Green Eggs and Ham
# 4                                        Goodnight Moon
# 5                                       Charlotte's Web
# 6                               Where the Sidewalk Ends
# 7                                    The Cat in the Hat
# ...                                                 ...
# 1192                     The Tale of Jemima Puddle-Duck
# 1193                    The Way Back Home (The Boy, #3)
# 1194                              What Was I Scared Of?
# 1195                        Strega Nona's Magic Lessons
# 1196  The Dot and the Line: A Romance in Lower Mathe...
# 1197      Are We There Yet?: A Journey Around Australia
# 1198                                          Drop Dead
# 1199              Mr. Putter &amp; Tabby Catch the Cold
#
# [1200 rows x 7 columns]

# %% [markdown]
# ## Analiza podatkov
#
# ### Najboljše knjige
#
# Najprej si oglejmo, katere so najbolje ocenjene knjige prve, druge in tretje liste.

# %%
# najboljše knjige liste 1
lista1.join(naslovi, on = 'id_nasl').head(10)[['mesto', 'ocena', 'st_glasov', 'ocena_skupaj', 'naslov']]
# Out:
#    mesto  ocena  st_glasov  ocena_skupaj  \
# 0      1   4.14    1021663        151594
# 1      2   4.11     657537        116234
# 2      3   4.19    1487021        113719
# 3      4   4.22     509181        107096
# 4      5   4.03    1262538         98256
# 5      6   4.28     449574         94659
# 6      7   4.10     483822         81032
# 7      8   4.22     607025         74583
# 8      9   4.04     613244         72375
# 9     10   4.15     167759         70652
#
#                                               naslov
# 0                                    Charlotte's Web
# 1                                  The Secret Garden
# 2  The Lion, the Witch, and the Wardrobe (Chronic...
# 3    Anne of Green Gables (Anne of Green Gables, #1)
# 4                    Little Women (Little Women, #1)
# 5                                            Matilda
# 6  Charlie and the Chocolate Factory (Charlie Buc...
# 7                          Where the Wild Things Are
# 8  A Wrinkle in Time (A Wrinkle in Time Quintet, #1)
# 9   Little House in the Big Woods (Little House, #1)

# %%
# najboljše knjige liste 2
lista2.join(naslovi, on = 'id_nasl').head(10)[['mesto', 'ocena', 'st_glasov', 'ocena_skupaj', 'naslov']]
# Out:
#    mesto  ocena  st_glasov  ocena_skupaj  \
# 0      1   4.43    4445378        193641
# 1      2   4.19     188942        105937
# 2      3   4.14    1021663        101622
# 3      4   4.19    1487021         87985
# 4      5   3.57    3734222         78428
# 5      6   4.04     613244         71259
# 6      7   4.11     657537         65743
# 7      8   4.35    4669681         65720
# 8      9   4.22     509181         62723
# 9     10   4.24    2102010         62677
#
#                                               naslov
# 0  Harry Potter and the Sorcerer's Stone (Harry P...
# 1     Little House on the Prairie (Little House, #2)
# 2                                    Charlotte's Web
# 3  The Lion, the Witch, and the Wardrobe (Chronic...
# 4                            Twilight (Twilight, #1)
# 5  A Wrinkle in Time (A Wrinkle in Time Quintet, #1)
# 6                                  The Secret Garden
# 7            The Hunger Games (The Hunger Games, #1)
# 8    Anne of Green Gables (Anne of Green Gables, #1)
# 9                                         The Hobbit

# %%
# najboljše knjige liste 3
lista3.join(naslovi, on = 'id_nasl').head(10)[['mesto', 'ocena', 'st_glasov', 'ocena_skupaj', 'naslov']]
# Out:
#    mesto  ocena  st_glasov  ocena_skupaj                        naslov
# 0      1   4.22     607025        106056     Where the Wild Things Are
# 1      2   4.28     289736        100936   The Very Hungry Caterpillar
# 2      3   4.38     673811         97748               The Giving Tree
# 3      4   4.29     452386         92798            Green Eggs and Ham
# 4      5   4.27     247113         73731                Goodnight Moon
# 5      6   4.14    1021663         69226               Charlotte's Web
# 6      7   4.28     997917         63486       Where the Sidewalk Ends
# 7      8   4.15     310680         62318            The Cat in the Hat
# 8      9   4.23     187460         60762  If You Give a Mouse a Cookie
# 9     10   4.34     154501         50881              Love You Forever

# %% [markdown]
# Na koliko listah se pojavi vsaka izmed zgoraj omenjenih knjig?

# %%
naj1 = lista1.join(naslovi, on = 'id_nasl').head(10)
naj2 = lista2.join(naslovi, on = 'id_nasl').head(10)
naj3 = lista3.join(naslovi, on = 'id_nasl').head(10)
pd.concat([naj1, naj2, naj3]).groupby('naslov').count()['mesto'].plot(kind='bar')

# %% [markdown]
# Samo ena knjiga se pojavi na vseh treh listah - Charlotte's web. Precej malo je tudi knjig, ki se pojavijo na vsaj dveh listah. Oglejmo si, kdo so njihovi avtorji.

# %%
naj1 = lista1.join(naslovi, on = 'id_nasl').head(10)
naj2 = lista2.join(naslovi, on = 'id_nasl').head(10)
naj3 = lista3.join(naslovi, on = 'id_nasl').head(10)
naj = pd.concat([naj1, naj2, naj3])
st_pojavitev = naj.groupby('naslov').count()[['mesto']]
st_pojavitev_2 = st_pojavitev[(st_pojavitev['mesto'] >= 2)]
naj.join(st_pojavitev_2, on = 'naslov', how = 'inner', lsuffix='_l', rsuffix='_r'
        ).join(avtorji, on = 'id_avt').drop_duplicates('naslov')[['naslov', 'avtor']]
# Out:
#                                               naslov                    avtor
# 0                                    Charlotte's Web               E.B. White
# 1                                  The Secret Garden  Frances Hodgson Burnett
# 2  The Lion, the Witch, and the Wardrobe (Chronic...               C.S. Lewis
# 3    Anne of Green Gables (Anne of Green Gables, #1)          L.M. Montgomery
# 7                          Where the Wild Things Are           Maurice Sendak
# 8  A Wrinkle in Time (A Wrinkle in Time Quintet, #1)    Madeleine L&#39;Engle

# %% [markdown]
# ### Najboljši avtorji
#
# Kdo so najboljši avtorji znotraj posamezne liste?

# %%
l1 = lista1.join(avtorji, on = 'id_avt').groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False).head()
display(l1[['ocena_skupaj']])
l2 = lista2.join(avtorji, on = 'id_avt').groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False).head()
display(l2[['ocena_skupaj']])
l3 = lista3.join(avtorji, on = 'id_avt').groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False).head()
display(l3[['ocena_skupaj']])
# Out:
#                          ocena_skupaj
# avtor
# E.B. White               62530.666667
# Frances Hodgson Burnett  59282.333333
# Johanna Spyri            57180.000000
# Scott O&#39;Dell         49650.000000
# Anne Frank               49363.000000
#                          ocena_skupaj
# avtor
# Harper Lee               50026.000000
# J.K. Rowling             49806.000000
# E.B. White               41207.333333
# Frances Hodgson Burnett  28425.000000
# Anne Frank               27774.000000
#                   ocena_skupaj
# avtor
# Don Freeman            46354.0
# Margery Williams       41825.0
# H.A. Rey               38907.0
# Jon Stone              37973.0
# Bill Martin Jr.        36578.5

# %% [markdown]
# Nekaj avtorjev se pojavi na več listah:

# %%
l1 = lista1.join(avtorji, on = 'id_avt').groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False).head()
l2 = lista2.join(avtorji, on = 'id_avt').groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False).head()
l3 = lista3.join(avtorji, on = 'id_avt').groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False).head()

ponavljajoci_avtorji = pd.concat([l1, l2, l3])[['ocena_skupaj']].reset_index(level=['avtor']).groupby('avtor').count()
ponavljajoci_avtorji[(ponavljajoci_avtorji['ocena_skupaj'] >= 2)]
# Out:
#                          ocena_skupaj
# avtor
# Anne Frank                          2
# E.B. White                          2
# Frances Hodgson Burnett             2

# %% [markdown]
# Kdo ima znotraj posamezne liste največje število knjig?

# %%
display(lista1.join(avtorji, on = 'id_avt')['avtor'].value_counts().head())
display(lista2.join(avtorji, on = 'id_avt')['avtor'].value_counts().head())
display(lista3.join(avtorji, on = 'id_avt')['avtor'].value_counts().head())
# Out:
# Enid Blyton       50
# Dr. Seuss         26
# Beverly Cleary    25
# Walter Farley     16
# Roald Dahl        15
# Name: avtor, dtype: int64
# Dr. Seuss        25
# Carolyn Keene    21
# Erin Hunter      19
# R.L. Stine       15
# Roald Dahl       13
# Name: avtor, dtype: int64
# Dr. Seuss          44
# Sandra Boynton     17
# Beverly Cleary     16
# L.M. Montgomery    16
# Roald Dahl         12
# Name: avtor, dtype: int64

# %% [markdown]
# Opazimo, da se imena avtorjev, ki imajo najboljšo skupno oceno ne ujemajo z imeni avtorjev, ki imajo na listah največ knjig. Bolj podrobno si bomo to povezavo ogledali v nadaljevanju, na listi, ki bo zajela knjige vseh treh list.

# %% [markdown]
# ### Skupna lista
# Združimo podatke vseh treh list. Kako si sledijo avtorji glede na skupno oceno na tej listi?

# %%
skupna_avtorji = pd.concat([lista1, lista2, lista3]).join(avtorji, on = 'id_avt')
skupna_avtorji.groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False)[:10]['ocena_skupaj']
# Out:
# avtor
# E.B. White                 43076.666667
# Margery Williams           34156.333333
# Frances Hodgson Burnett    32952.333333
# Harper Lee                 32820.333333
# Don Freeman                30652.666667
# Antoine de Saint-Exupry    29593.333333
# Johanna Spyri              28224.666667
# Anne Frank                 26714.000000
# Jon Stone                  26528.333333
# Shel Silverstein           26039.882353
# Name: ocena_skupaj, dtype: float64

# %% [markdown]
# Kako pada priljubljenost med prvimi desetimi avtorji?

# %%
skupna_avtorji.groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False)[:10]['ocena_skupaj'
                                                                                        ].plot().set_ylabel("skupna ocena")

# %% [markdown]
# Avtor E. B. White ima precej boljšo oceno kot drugo uvrščeni Margery Williams. Potem razlike med doseženo oceno padajo bolj položno in skoraj linearno. Med 8. mestom (Anne Frank) in 10. mestom (Shel Silverstein) se razlika močno zmanjša - znaša približno 700 točk.

# %% [markdown]
# Kateri avtor ima največ knjig na skupni listi?

# %%
skupna_avtorji.groupby('avtor').size().sort_values(ascending=False)
# Out:
# avtor
# Dr. Seuss          95
# Enid Blyton        68
# Beverly Cleary     53
# Roald Dahl         40
# L.M. Montgomery    31
# Carolyn Keene      31
# R.L. Stine         29
# Judy Blume         28
#                    ..
# Keith Faulkner      1
# Keiko Kasza         1
# Kazuo Ishiguro      1
# Kazu Kibuishi       1
# Kathryn Otoshi      1
# Kathryn Lasky       1
# Kathryn Kenny       1
# Johnny Gruelle      1
# dtype: int64

# %% [markdown]
# Največ knjig na skupni listi ima Dr. Seuss. Da bomo imeli boljši pregled nad tem, kako št. knjig posameznega avtorja pada, si oglejmo graf za prvih 50 avtorjev.

# %%
skupna_avtorji.groupby('avtor').size().sort_values(ascending=False)[:50].plot(kind='bar').set_ylabel("število knjig")

# %% [markdown]
# Podobno kot pri prejšnjem grafu, najbolje uvrščeni avtorj s precejšnjo razliko odstopa od ostalih. Na prvih nekaj mestih so potem razlike v številu knjig še precej velike, potem pa postopno upadajo. Grafa sta si po lastnostih verjetno podobna zato, ker ljudje pri otroških knjigah ponavadi močno favorizirajo enega avtorja oz. eno uspešnico. Zato prvi avtor precej bolj izstopa. Naslednjih nekaj avtorjev je še zelo dobro uvrščenih, zato na začetku graf tudi bolj strmo pada. (Emocionalnost ljudi). Potem pa se razlike zmanjšajo, ker se mnenja začnejo bolj deliti, knjige, ki so komu všeč, komu niso...

# %% [markdown]
# Poglejmo si sedaj, kakšna je povezava med št. knjig, ki jih ima avtor ter povprečno skupno oceno:

# %%
skupna_avtorji = pd.concat([lista1, lista2, lista3]).join(avtorji, on = 'id_avt')
na_oceno = skupna_avtorji.groupby('avtor').mean().sort_values('ocena_skupaj', ascending=False)[['ocena_skupaj']]
na_stevilo_knj = skupna_avtorji.groupby('avtor').count()[['mesto']].sort_values('mesto', ascending=False)
zdruzen = pd.concat((na_oceno, na_stevilo_knj), axis = 1).rename(index=str, columns={"mesto": "stevilo knjig"})
zdruzen.plot(kind='scatter', x = 'ocena_skupaj', y = 'stevilo knjig', color='w')

# %% [markdown]
# Kot že rečeno, imajo avtorji, ki so visoko uvrščeni glede na skupno oceno, malo knjig na listah in obratno????

# %% [markdown]
# Oglejmo si še, kako je porazdeljena ocena znotraj posamezne liste. Ker je skupna ocena odvisna tudi od ocene, ta zagotovo vpliva tudi na zgornje rezultate.

# %%
def GroupFunc(x):
    if x >= 4.5:
        return 'večja od 4.5'
    elif x >= 4.0 :
        return 'večja od 4.0'
    elif x >= 3.5:
        return 'večja od 3.5'
    else:
        return 'manjša od 3.5'
    

a = lista1.set_index(['ocena']).groupby(GroupFunc).count()
a[['mesto']].plot(kind='pie',figsize=(4, 4), legend=False, subplots=True)
b = lista2.set_index(['ocena']).groupby(GroupFunc).count()
b[['mesto']].plot(kind='pie',figsize=(4, 4), legend=False, subplots=True)
c = lista3.set_index(['ocena']).groupby(GroupFunc).count()
c[['mesto']].plot(kind='pie',figsize=(4, 4), legend=False, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000149FBCC2630>], dtype=object)

# %% [markdown]
# Pri vseh treh listah je največji delež knjig imelo oceno med 4.0 in 4.5. Precej močno so zastopane še ocene med 3.5 in 4.0.

# %% [markdown]
# ### Knjige, ki so se uvrstile na vse tri liste
#
# Želimo ustvariti listo knjig, ki so se uvrstile na vse tri liste in jih urediti glede na skupno oceno. Najprej si oglejmo, katere knjige so se pojavile na vseh treh listah. Razvrstimo naslove glede na število ponovitev.

# %%
skupna_naslovi = pd.concat([lista1, lista2, lista3]).join(naslovi, on = 'id_nasl')
skupna_naslovi.groupby('naslov').size().sort_values(ascending=False)
# Out:
# naslov
# Stone Soup                                               6
# Black Beauty                                             4
# George's Marvellous Medicine                             3
# Tales of a Fourth Grade Nothing (Fudge, #1)              3
# The Tale of Despereaux                                   3
# Go, Dog. Go!                                             3
# The Tale of Mrs. Tittlemouse                             3
# The Tale of Peter Rabbit                                 3
#                                                         ..
# Stone Fox                                                1
# Stories of Queens Day                                    1
# Stormbreaker (Alex Rider, #1)                            1
# Stormqueen!  (Darkover - Chronological Order #3)         1
# Stormy, Misty's Foal (Misty, #3)                         1
# Stowaway to the Mushroom Planet (Mushroom Planet, #2)    1
# Stranger with My Face                                    1
# Outlander (Outlander #1)                                 1
# dtype: int64

# %% [markdown]
# Opazimo, da se nekateri naslovi ponovijo več kot trikrat. Kaj je razlog?
# Poglejmo si na primeru knjige z naslovom Stone Soup:

# %%
lista3.join(naslovi, on = 'id_nasl').join(avtorji, on = 'id_avt')[
    lista3.join(naslovi, on = 'id_nasl').join(avtorji, on = 'id_avt')['naslov'] == 'Stone Soup']
# Out:
#       mesto  id_nasl   id_avt  ocena  st_glasov  ocena_skupaj      naslov  \
# 96       97   331701    12733   4.14      12672          9369  Stone Soup
# 802     800   193093   112477   4.22      36757           247  Stone Soup
# 823     822  2687495  1179479   4.08        377           231  Stone Soup
# 1101   1102  1031461      179   4.27      24895           158  Stone Soup
#
#                  avtor
# 96         Jon J. Muth
# 802       Marcia Brown
# 823   Marilyn Sapienza
# 1101      Ann McGovern

# %% [markdown]
# Razlog je, da je knjigo s tem naslovom napisalo več različnih avtorjev. Ko razvrstimo knjige glede na avtorje in naslove, dobimo željen seznam:

# %%
skupna_naslovi.join(avtorji, on = 'id_avt').groupby(['naslov', 'avtor']).size().sort_values(ascending=False)
# Out:
# naslov                                            avtor
# Pinocchio                                         Carlo Collodi            3
# Emily of New Moon (Emily, #1)                     L.M. Montgomery          3
# The Westing Game                                  Ellen Raskin             3
# Blueberries for Sal                               Robert McCloskey         3
# And to Think That I Saw it on Mulberry Street     Dr. Seuss                3
# The Dark Is Rising (The Dark is Rising, #2)       Susan Cooper             3
# Hatchet (Brian's Saga, #1)                        Gary Paulsen             3
# The White Mountains (The Tripods, #1)             John Christopher         3
#                                                                           ..
# Stone Soup                                        Jess Stockham            1
#                                                   Jon J. Muth              1
#                                                   Marilyn Sapienza         1
# Stories of Queens Day                             Mark  Miller             1
# Stormbreaker (Alex Rider, #1)                     Anthony Horowitz         1
# Stormqueen!  (Darkover - Chronological Order #3)  Marion Zimmer Bradley    1
# Stormy, Misty's Foal (Misty, #3)                  Marguerite Henry         1
#                                                   Gianni Rodari            1
# dtype: int64

# %% [markdown]
# Končno lahko ustvarimo tabelo naslovov, ki so se uvrstili na vse tri liste.

# %%
st_ponovitev = skupna_naslovi.join(avtorji, on = 'id_avt').groupby(['avtor','naslov']).count()
st_ponovitev[st_ponovitev.id_nasl == 3]
# Out:
#                                                                         mesto  \
# avtor                   naslov
# A.A. Milne              The House at Pooh Corner (Winnie-the-Pooh, #2)      3
#                         When We Were Very Young (Winnie-the-Pooh, #3)       3
#                         Winnie-the-Pooh (Winnie-the-Pooh, #1)               3
# Aesop                   Aesop's Fables                                      3
# Anna Sewell             Black Beauty                                        3
# Anne Frank              The Diary of a Young Girl                           3
# Antoine de Saint-Exupry The Little Prince                                   3
# Arnold Lobel            Frog and Toad Are Friends (Frog and Toad, #1)       3
# ...                                                                       ...
# Virginia Lee Burton     Mike Mulligan and His Steam Shovel                  3
#                         The Little House                                    3
# Walter Farley           The Black Stallion (The Black Stallion, #1)         3
# Wanda Gg                Millions of Cats                                    3
# Watty Piper             The Little Engine That Could                        3
# Wilson Rawls            Where the Red Fern Grows                            3
# Zilpha Keatley Snyder   The Changeling                                      3
#                         The Egypt Game (Game, #1)                           3
#
#                                                                         id_nasl  \
# avtor                   naslov
# A.A. Milne              The House at Pooh Corner (Winnie-the-Pooh, #2)        3
#                         When We Were Very Young (Winnie-the-Pooh, #3)         3
#                         Winnie-the-Pooh (Winnie-the-Pooh, #1)                 3
# Aesop                   Aesop's Fables                                        3
# Anna Sewell             Black Beauty                                          3
# Anne Frank              The Diary of a Young Girl                             3
# Antoine de Saint-Exupry The Little Prince                                     3
# Arnold Lobel            Frog and Toad Are Friends (Frog and Toad, #1)         3
# ...                                                                         ...
# Virginia Lee Burton     Mike Mulligan and His Steam Shovel                    3
#                         The Little House                                      3
# Walter Farley           The Black Stallion (The Black Stallion, #1)           3
# Wanda Gg                Millions of Cats                                      3
# Watty Piper             The Little Engine That Could                          3
# Wilson Rawls            Where the Red Fern Grows                              3
# Zilpha Keatley Snyder   The Changeling                                        3
#                         The Egypt Game (Game, #1)                             3
#
#                                                                         id_avt  \
# avtor                   naslov
# A.A. Milne              The House at Pooh Corner (Winnie-the-Pooh, #2)       3
#                         When We Were Very Young (Winnie-the-Pooh, #3)        3
#                         Winnie-the-Pooh (Winnie-the-Pooh, #1)                3
# Aesop                   Aesop's Fables                                       3
# Anna Sewell             Black Beauty                                         3
# Anne Frank              The Diary of a Young Girl                            3
# Antoine de Saint-Exupry The Little Prince                                    3
# Arnold Lobel            Frog and Toad Are Friends (Frog and Toad, #1)        3
# ...                                                                        ...
# Virginia Lee Burton     Mike Mulligan and His Steam Shovel                   3
#                         The Little House                                     3
# Walter Farley           The Black Stallion (The Black Stallion, #1)          3
# Wanda Gg                Millions of Cats                                     3
# Watty Piper             The Little Engine That Could                         3
# Wilson Rawls            Where the Red Fern Grows                             3
# Zilpha Keatley Snyder   The Changeling                                       3
#                         The Egypt Game (Game, #1)                            3
#
#                                                                         ocena  \
# avtor                   naslov
# A.A. Milne              The House at Pooh Corner (Winnie-the-Pooh, #2)      3
#                         When We Were Very Young (Winnie-the-Pooh, #3)       3
#                         Winnie-the-Pooh (Winnie-the-Pooh, #1)               3
# Aesop                   Aesop's Fables                                      3
# Anna Sewell             Black Beauty                                        3
# Anne Frank              The Diary of a Young Girl                           3
# Antoine de Saint-Exupry The Little Prince                                   3
# Arnold Lobel            Frog and Toad Are Friends (Frog and Toad, #1)       3
# ...                                                                       ...
# Virginia Lee Burton     Mike Mulligan and His Steam Shovel                  3
#                         The Little House                                    3
# Walter Farley           The Black Stallion (The Black Stallion, #1)         3
# Wanda Gg                Millions of Cats                                    3
# Watty Piper             The Little Engine That Could                        3
# Wilson Rawls            Where the Red Fern Grows                            3
# Zilpha Keatley Snyder   The Changeling                                      3
#                         The Egypt Game (Game, #1)                           3
#
#                                                                         st_glasov  \
# avtor                   naslov
# A.A. Milne              The House at Pooh Corner (Winnie-the-Pooh, #2)          3
#                         When We Were Very Young (Winnie-the-Pooh, #3)           3
#                         Winnie-the-Pooh (Winnie-the-Pooh, #1)                   3
# Aesop                   Aesop's Fables                                          3
# Anna Sewell             Black Beauty                                            3
# Anne Frank              The Diary of a Young Girl                               3
# Antoine de Saint-Exupry The Little Prince                                       3
# Arnold Lobel            Frog and Toad Are Friends (Frog and Toad, #1)           3
# ...                                                                           ...
# Virginia Lee Burton     Mike Mulligan and His Steam Shovel                      3
#                         The Little House                                        3
# Walter Farley           The Black Stallion (The Black Stallion, #1)             3
# Wanda Gg                Millions of Cats                                        3
# Watty Piper             The Little Engine That Could                            3
# Wilson Rawls            Where the Red Fern Grows                                3
# Zilpha Keatley Snyder   The Changeling                                          3
#                         The Egypt Game (Game, #1)                               3
#
#                                                                         ocena_skupaj
# avtor                   naslov
# A.A. Milne              The House at Pooh Corner (Winnie-the-Pooh, #2)             3
#                         When We Were Very Young (Winnie-the-Pooh, #3)              3
#                         Winnie-the-Pooh (Winnie-the-Pooh, #1)                      3
# Aesop                   Aesop's Fables                                             3
# Anna Sewell             Black Beauty                                               3
# Anne Frank              The Diary of a Young Girl                                  3
# Antoine de Saint-Exupry The Little Prince                                          3
# Arnold Lobel            Frog and Toad Are Friends (Frog and Toad, #1)              3
# ...                                                                              ...
# Virginia Lee Burton     Mike Mulligan and His Steam Shovel                         3
#                         The Little House                                           3
# Walter Farley           The Black Stallion (The Black Stallion, #1)                3
# Wanda Gg                Millions of Cats                                           3
# Watty Piper             The Little Engine That Could                               3
# Wilson Rawls            Where the Red Fern Grows                                   3
# Zilpha Keatley Snyder   The Changeling                                             3
#                         The Egypt Game (Game, #1)                                  3
#
# [251 rows x 6 columns]

# %% [markdown]
# Sedaj izračunamo povprečno skupno oceno posameznega naslova, jih ustrezno razvrstimo in jim dodelimo mesta.
# Končna lista:

# %%
#generiramo novo listo s knjigami, ki se pojavijo na vseh treh listah in izračunamo njihovo povprečno skupno oceno
skupna = skupna_naslovi.join(avtorji, on = 'id_avt').set_index(['avtor', 'naslov'])
st_ponovitev = skupna_naslovi.join(avtorji, on = 'id_avt').groupby(['avtor','naslov']).count()
ustrezna = st_ponovitev[st_ponovitev.mesto == 3].reset_index(level=['avtor','naslov'])[['avtor', 'naslov']]
ustrezna.join(skupna, on=['avtor', 'naslov']).groupby('naslov').mean()[
    ['ocena','st_glasov', 'ocena_skupaj']].sort_values('ocena_skupaj', ascending=False).reset_index(level=['naslov'])
# Out:
#                                                 naslov  ocena     st_glasov  \
# 0                                      Charlotte's Web   4.14  1.021663e+06
# 1    Harry Potter and the Sorcerer's Stone (Harry P...   4.43  4.445378e+06
# 2    The Lion, the Witch, and the Wardrobe (Chronic...   4.19  1.487021e+06
# 3                            Where the Wild Things Are   4.22  6.070250e+05
# 4                                    The Secret Garden   4.11  6.575370e+05
# 5                                   Green Eggs and Ham   4.29  4.523860e+05
# 6      Anne of Green Gables (Anne of Green Gables, #1)   4.22  5.091810e+05
# 7                              Where the Sidewalk Ends   4.28  9.979170e+05
# ..                                                 ...    ...           ...
# 243                                   The Pushcart War   4.12  2.910000e+03
# 244                 Dicey's Song (Tillerman Cycle, #2)   3.94  1.533900e+04
# 245                                Kirsten's Boxed Set   4.00  4.900000e+03
# 246  The Black Cauldron (The Chronicles of Prydain #2)   4.13  5.011567e+04
# 247   Second Form at Malory Towers (Malory Towers, #2)   4.02  7.328000e+03
# 248                                      The 13 Clocks   4.04  4.606000e+03
# 249                                     The Changeling   4.15  1.192000e+03
# 250   Jeremy Thatcher, Dragon Hatcher (Magic Shop, #2)   4.01  6.556000e+03
#
#       ocena_skupaj
# 0    107480.666667
# 1     98559.000000
# 2     71528.000000
# 3     70154.333333
# 4     69654.666667
# 5     66714.000000
# 6     64271.000000
# 7     63148.333333
# ..             ...
# 243     474.666667
# 244     427.666667
# 245     404.000000
# 246     394.000000
# 247     368.333333
# 248     335.666667
# 249     274.000000
# 250     268.333333
#
# [251 rows x 4 columns]

# %% [markdown]
# Kako so uvrščene knjige glede na število glasov?

# %%
ustrezna.join(skupna, on=['avtor', 'naslov']).groupby('naslov').mean()[
    ['ocena','st_glasov', 'ocena_skupaj']].sort_values('st_glasov', ascending=False)
# Out:
#                                                     ocena     st_glasov  \
# naslov
# The Hunger Games (The Hunger Games, #1)              4.35  4.671110e+06
# Harry Potter and the Sorcerer's Stone (Harry Po...   4.43  4.445378e+06
# To Kill a Mockingbird                                4.25  3.197767e+06
# The Hobbit                                           4.24  2.102010e+06
# The Diary of a Young Girl                            4.09  1.959160e+06
# Animal Farm                                          3.86  1.898145e+06
# Harry Potter and the Prisoner of Azkaban (Harry...   4.52  1.857437e+06
# Harry Potter and the Chamber of Secrets (Harry ...   4.36  1.795447e+06
# ...                                                   ...           ...
# Me Too!                                              4.14  4.828000e+03
# The 13 Clocks                                        4.04  4.606000e+03
# Seven-Day Magic (Tales of Magic, #7)                 4.12  4.119000e+03
# The Pushcart War                                     4.12  2.910000e+03
# The Tale of Mrs. Tittlemouse                         3.95  2.678000e+03
# The Wonderful Flight to the Mushroom Planet (Mu...   4.01  1.811000e+03
# The Changeling                                       4.15  1.192000e+03
# Uncle Remus Stories                                  4.17  8.320000e+02
#
#                                                     ocena_skupaj
# naslov
# The Hunger Games (The Hunger Games, #1)             23047.666667
# Harry Potter and the Sorcerer's Stone (Harry Po...  98559.000000
# To Kill a Mockingbird                               32820.333333
# The Hobbit                                          50058.333333
# The Diary of a Young Girl                           26714.000000
# Animal Farm                                          1102.333333
# Harry Potter and the Prisoner of Azkaban (Harry...  22688.666667
# Harry Potter and the Chamber of Secrets (Harry ...  20680.666667
# ...                                                          ...
# Me Too!                                               902.666667
# The 13 Clocks                                         335.666667
# Seven-Day Magic (Tales of Magic, #7)                  477.000000
# The Pushcart War                                      474.666667
# The Tale of Mrs. Tittlemouse                          783.666667
# The Wonderful Flight to the Mushroom Planet (Mu...    571.333333
# The Changeling                                        274.000000
# Uncle Remus Stories                                  1134.333333
#
# [251 rows x 3 columns]

# %%
#generiramo novo listo glede na oceno
ustrezna.join(skupna, on=['avtor', 'naslov']).groupby('naslov').mean()[
    ['ocena','st_glasov', 'ocena_skupaj']].sort_values('ocena', ascending=False)
# Out:
#                                                     ocena     st_glasov  \
# naslov
# The Authoritative Calvin and Hobbes: A Calvin a...   4.73  1.760633e+04
# Harry Potter and the Deathly Hallows (Harry Pot...   4.61  1.748999e+06
# Harry Potter and the Half-Blood Prince (Harry P...   4.53  1.692827e+06
# Harry Potter and the Goblet of Fire (Harry Pott...   4.52  1.763333e+06
# Harry Potter and the Prisoner of Azkaban (Harry...   4.52  1.857437e+06
# The Jolly Postman, or Other People's Letters         4.48  9.732000e+03
# The Lord of the Rings (The Lord of the Rings, #...   4.47  4.157183e+05
# Harry Potter and the Order of the Phoenix (Harr...   4.46  1.757268e+06
# ...                                                   ...           ...
# Roll of Thunder, Hear My Cry (Logans, #4)            3.78  9.470800e+04
# How to Eat Fried Worms                               3.74  3.740000e+04
# Sarah, Plain and Tall (Sarah, Plain and Tall, #1)    3.72  5.862367e+04
# Dear Mr. Henshaw (Leigh Botts, #1)                   3.69  2.892000e+04
# Hatchet (Brian's Saga, #1)                           3.67  2.213080e+05
# Summer of My German Soldier (Summer of My Germa...   3.65  1.379900e+04
# Charlie and the Great Glass Elevator (Charlie B...   3.63  6.566733e+04
# Johnny Tremain                                       3.61  3.168867e+04
#
#                                                     ocena_skupaj
# naslov
# The Authoritative Calvin and Hobbes: A Calvin a...    960.333333
# Harry Potter and the Deathly Hallows (Harry Pot...  15952.000000
# Harry Potter and the Half-Blood Prince (Harry P...  13384.666667
# Harry Potter and the Goblet of Fire (Harry Pott...  18700.666667
# Harry Potter and the Prisoner of Azkaban (Harry...  22688.666667
# The Jolly Postman, or Other People's Letters          576.666667
# The Lord of the Rings (The Lord of the Rings, #...  11838.000000
# Harry Potter and the Order of the Phoenix (Harr...  10017.666667
# ...                                                          ...
# Roll of Thunder, Hear My Cry (Logans, #4)            3442.333333
# How to Eat Fried Worms                              10152.666667
# Sarah, Plain and Tall (Sarah, Plain and Tall, #1)    2625.333333
# Dear Mr. Henshaw (Leigh Botts, #1)                   1552.000000
# Hatchet (Brian's Saga, #1)                           4545.000000
# Summer of My German Soldier (Summer of My Germa...   1793.333333
# Charlie and the Great Glass Elevator (Charlie B...   3499.000000
# Johnny Tremain                                       3669.333333
#
# [251 rows x 3 columns]

# %%
#ta graf prikazuje odvisnost skupne ocene od uvrščenega mesta.
a = ustrezna.join(skupna, on=['avtor', 'naslov']).groupby('naslov').mean()[
    ['ocena','st_glasov', 'ocena_skupaj']].sort_values('ocena_skupaj', ascending=False).reset_index(level=['naslov'])
g = a['ocena_skupaj'].plot()
g.set_xlabel("mesto")
g.set_ylabel("ocena skupaj")
